# %% [markdown]
# <a href="https://colab.research.google.com/github/oscarWoj/CISC499/blob/main/499_bertopic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bertopic Model
# This .ipynb takes a parsed csv file of conversations on a dark web forum and trains a topic modelling AI called BERTOPIC
# - More info on BERTopic: https://towardsdatascience.com/interactive-topic-modeling-with-bertopic-1ea55e7d73d8

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Data will be downloaded from google drive folder

# %%
# !pip install bertopic[visualization]
# !apt-get install unzip
# !pip install gdown
# !pip install --upgrade gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 KB 3.9 MB/s eta 0:00:00
# WARNING: bertopic 0.14.0 does not provide the extra 'visualization'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 51.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 86.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 22.7 MB/s eta 0:00:00
# ...

# %%
import csv
import gdown
from bertopic import BERTopic

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1Xtc9eTSyjQEaGoRgU9VGlz6YB4SvPoMc/view?usp=sharing
# !gdown --fuzzy https://drive.google.com/file/d/1KvbaoIV18t7bMboOAJfkgyrf5ENGiSWH/view?usp=share_link
# !gdown --fuzzy https://drive.google.com/file/d/1RmIhftc9tRw4MMC_f_oSdhPsVb1NoqpZ/view?usp=share_link

# %%
# !unzip /content/outputfile.csv.zip
# !unzip /content/output_simple.csv.zip
# !unzip /content/output_complex.csv.zip
# Out:
# Archive:  /content/outputfile.csv.zip
#   inflating: outputfile.csv
#   inflating: __MACOSX/._outputfile.csv
# Archive:  /content/output_simple.csv.zip
#   inflating: output_simple.csv
# Archive:  /content/output_complex.csv.zip
#   inflating: output_complex.csv

# %%
data = [] ## IF the system keeps running out of memory, we might have to change this list of string into a numpy object thingn

# %%
with open('/content/output_complex.csv', newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row[0])

# %%
data[0]
# Out:
# 'text'

# %%
type(data[0]) # This should be string not list

# %%
len (data)

# %% [markdown]
# ## Implementing and running the model

# %%
sample = True

# %%
model = BERTopic()
if sample:
  topics, probs = model.fit_transform(data[:500000])
else:
  topics, probs = model.fit_transform(data)

# %%
model.get_topic_freq().head()

# %%
#hierarchical_topics = model.hierarchical_topics(data)

# Print topic tree
#tree = model.get_topic_tree(hierarchical_topics)
#print(tree)

# %%
model.visualize_topics()

# %%
if sample:
  model.save("sample_model")
else:
  model.save("full_model_complex_or_simple")

# %% [markdown]
# Zip extracted Bertopic model and extract into google drive

# %%
# Change name to better match the model trained (data 'class' and size)
# !zip model_with_descriptive_name.zip full_model_complex_or_simple
