# %% [markdown]
# <a href="https://colab.research.google.com/github/oscarWoj/CISC499/blob/main/499_bertopic2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Refer to this if you have any questions: https://towardsdatascience.com/interactive-topic-modeling-with-bertopic-1ea55e7d73d8

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Data will be downloaded from google drive folder

# %%
# !pip install numpy~=1.20.0
# !pip install bertopic
# !sudo apt-get install unzip
# !pip install gdown
# !pip install --upgrade gdown
# Out:
# Requirement already satisfied: numpy~=1.20.0 in /opt/conda/lib/python3.8/site-packages (1.20.3)
# Requirement already satisfied: bertopic in /opt/conda/lib/python3.8/site-packages (0.14.1)
# Requirement already satisfied: umap-learn>=0.5.0 in /opt/conda/lib/python3.8/site-packages (from bertopic) (0.5.3)
# Requirement already satisfied: pandas>=1.1.5 in /opt/conda/lib/python3.8/site-packages (from bertopic) (1.1.5)
# Requirement already satisfied: plotly>=4.7.0 in /opt/conda/lib/python3.8/site-packages (from bertopic) (4.8.2)
# Requirement already satisfied: hdbscan>=0.8.29 in /opt/conda/lib/python3.8/site-packages (from bertopic) (0.8.29)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /opt/conda/lib/python3.8/site-packages (from bertopic) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /opt/conda/lib/python3.8/site-packages (from bertopic) (4.62.3)
# Requirement already satisfied: numpy>=1.20.0 in /opt/conda/lib/python3.8/site-packages (from bertopic) (1.20.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /opt/conda/lib/python3.8/site-packages (from bertopic) (0.24.2)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.8/site-packages (from hdbscan>=0.8.29->bertopic) (1.5.3)
# Requirement already satisfied: joblib>=1.0 in /opt/conda/lib/python3.8/site-packages (from hdbscan>=0.8.29->bertopic) (1.1.0)
# Requirement already satisfied: cython>=0.27 in /opt/conda/lib/python3.8/site-packages (from hdbscan>=0.8.29->bertopic) (0.29.27)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.8/site-packages (from pandas>=1.1.5->bertopic) (2021.3)
# Requirement already satisfied: retrying>=1.3.3 in /opt/conda/lib/python3.8/site-packages (from plotly>=4.7.0->bertopic) (1.3.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from plotly>=4.7.0->bertopic) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.10.0+cu111)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (1.9.0+cu111)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /opt/conda/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.12.1)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.97)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/conda/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.26.1)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.8/site-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: numba>=0.49 in /opt/conda/lib/python3.8/site-packages (from umap-learn>=0.5.0->bertopic) (0.52.0)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.8/site-packages (from umap-learn>=0.5.0->bertopic) (0.5.8)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.7.4.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: llvmlite<0.36,>=0.35.0 in /opt/conda/lib/python3.8/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.35.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (59.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.1.18)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.13.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.8/site-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Requirement already satisfied: pillow>=5.3.0 in /opt/conda/lib/python3.8/site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.0.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.8/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.8)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1.2).
# 0 upgraded, 0 newly installed, 0 to remove and 193 not upgraded.
# Requirement already satisfied: gdown in /opt/conda/lib/python3.8/site-packages (4.6.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from gdown) (1.15.0)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.8/site-packages (from gdown) (2.27.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.8/site-packages (from gdown) (3.9.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.8/site-packages (from gdown) (4.9.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.8/site-packages (from gdown) (4.62.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.8/site-packages (from beautifulsoup4->gdown) (2.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (2.0.11)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: gdown in /opt/conda/lib/python3.8/site-packages (4.6.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.8/site-packages (from gdown) (3.9.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from gdown) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.8/site-packages (from gdown) (4.9.3)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.8/site-packages (from gdown) (2.27.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.8/site-packages (from gdown) (4.62.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.8/site-packages (from beautifulsoup4->gdown) (2.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (2.0.11)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (2021.10.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.8/site-packages (from requests[socks]->gdown) (1.7.1)

# %%
#!pip install llvmlite --ignore-installed
#!pip install cudf-cu11 dask-cudf-cu11 --extra-index-url=https://pypi.ngc.nvidia.com
#!pip install cuml-cu11 --extra-index-url=https://pypi.ngc.nvidia.com
#!pip install cugraph-cu11 --extra-index-url=https://pypi.ngc.nvidia.com
#!pip uninstall cupy-cuda115 -y
#!pip uninstall cupy-cuda11x -y
#!pip install cupy-cuda11x -f https://pip.cupy.dev/aarch64

#!pip install cudf-cu11 dask-cudf-cu11 --extra-index-url=https://pypi.ngc.nvidia.com
#!pip install cuml-cu11 --extra-index-url=https://pypi.ngc.nvidia.com
#!pip install cugraph-cu11 --extra-index-url=https://pypi.ngc.nvidia.com
#!pip uninstall cupy-cuda115 -y
#!pip uninstall cupy-cuda11x -y
#!pip install cupy-cuda11x -f https://pip.cupy.dev/aarch64

# %%
#from cuml.cluster import HDBSCAN
#from cuml.manifold import UMAP

# %%
import torch
import csv
import gdown
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

from sklearn.decomposition import PCA
import numpy as np

# %%
from umap import UMAP

# %%
#device = ‘cuda’ if torch.cuda.is_available() else ‘cpu’

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### You can skip the next 2 lines if data is already in

# %%
#!gdown -v --fuzzy https://drive.google.com/file/d/1Xtc9eTSyjQEaGoRgU9VGlz6YB4SvPoMc/view?usp=sharing
#!gdown --fuzzy https://drive.google.com/file/d/1KvbaoIV18t7bMboOAJfkgyrf5ENGiSWH/view?usp=share_link
# !gdown --fuzzy https://drive.google.com/file/d/1RmIhftc9tRw4MMC_f_oSdhPsVb1NoqpZ/view?usp=share_link
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1RmIhftc9tRw4MMC_f_oSdhPsVb1NoqpZ
# To: /home/jovyan/project/CISC499/output_complex.csv.zip
# 100%|████████████████████████████████████████| 784M/784M [00:10<00:00, 73.9MB/s]

# %%
# !unzip -vo ~/project/CISC499/output_complex.csv.zip
#!unzip ~/project/CISC499/output_simple.csv.zip
#!unzip ~/project/CISC499/outputfile.csv.zip
# Out:
# Archive:  /home/jovyan/project/CISC499/output_complex.csv.zip
#  Length   Method    Size  Cmpr    Date    Time   CRC-32   Name
# --------  ------  ------- ---- ---------- ----- --------  ----
# 2710034252  Defl:N 784241998  71% 2023-02-15 04:47 32926c1e  output_complex.csv
# --------          -------  ---                            -------
# 2710034252         784241998  71%                            1 file

# %% [markdown]
# ### Reading Data

# %%
data = []
with open(r'output_complex.csv', newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row[0])

# %%
data[8]
# Out:
# 'a lot of big website use cloaking too   i have heard amazon com uses cloaking '

# %%
#data[8][2]

# %%
#parsed_data=[]

# %%
data[0]
# Out:
# 'text'

# %% [markdown]
# ## Optimizing and running the model

# %% [markdown]
# ## change to CPU only - Optimization -1

# %%
#from sklearn.pipeline import make_pipeline
#from sklearn.decomposition import TruncatedSVD
#from sklearn.feature_extraction.text import TfidfVectorizer

#pipe = make_pipeline(
 #   TfidfVectorizer(),
 #   TruncatedSVD(100))

#topic_model_nocpu = BERTopic(embedding_model=pipe)

# %% [markdown]
# ### Precompute Embeddings - Optimization #1

# %%
sentence_model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
embeddings = sentence_model.encode(data[1:], show_progress_bar=True)
# Takes ~ 40 Mins w/ max cluster settings
# Out:
# Batches:   0%|          | 0/311751 [00:00<?, ?it/s]

# %%
#Embeddings sample
embeddings_sample = sentence_model.encode(data[1:len(data)//4], show_progress_bar=True)
# Takes ~ 20 min w/ max cluster settings
# Out:
# Batches:   0%|          | 0/155875 [00:00<?, ?it/s]

# %% [markdown]
# ### Speed up umap - Optimization #2

# %%
def rescale(x, inplace=False):
    """ Rescale an embedding so optimization will not have convergence issues.
    """
    if not inplace:
        x = np.array(x, copy=True)

    x /= np.std(x[:, 0]) * 10000

    return x

# %%
# Initialize and rescale PCA embeddings
pca_embeddings = rescale(PCA(n_components=5).fit_transform(embeddings))

# %%
pca_embeddings_sample = rescale(PCA(n_components=5).fit_transform(embeddings_sample))

# %%
# Start UMAP from PCA embeddings
umap_model = UMAP(
    n_neighbors=15,
    n_components=5, #5
    min_dist=0.0,
    metric="cosine",
    init=pca_embeddings,
    low_memory=True
)

# %%
umap_model_sample = UMAP(
    n_neighbors=15,
    n_components=5,
    min_dist=0.0,
    metric="cosine",
    init=pca_embeddings_sample,
    low_memory=True
)

# %% [markdown]
# ### Putting it all together

# %%
sample = True

# %%
# !date
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Mon Mar  6 16:54:31 UTC 2023

# %%
#train on only cpu - lighweight
#if sample:
#    topic_model_nogpu = BERTopic(embedding_model=pipe,umap_model=umap_model_sample,verbose=True,min_topic_size=100,n_gram_range=(1,2))
#    topics, probs = topic_model_nogpu.fit_transform(data[1:len(data)//2])
#else:
#    topic_model_nogpu = BERTopic(embedding_model=pipe,umap_model=umap_model,verbose=True,min_topic_size=100,n_gram_range=(1,2))
#    topics, probs = topic_model_nogpu.fit_transform(data[1:])

# %%
# !date
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Mon Mar  6 16:54:31 UTC 2023

# %%
# !date
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Mon Mar  6 16:54:32 UTC 2023

# %%
#train on both (using gpu isnt necessarily "correct" on jupyterlab instance)
if sample:
    topic_model_gpu = BERTopic(umap_model=umap_model_sample,verbose=True,min_topic_size=300,n_gram_range=(1,2))
    topics2, probs2 = topic_model_gpu.fit_transform(data[1:len(data)//4], embeddings_sample)
else:
    topic_model_gpu = BERTopic(umap_model=umap_model,verbose=True,min_topic_size=400,n_gram_range=(1,2))
    topics2, probs2 = topic_model_gpu.fit_transform(data[1:], embeddings)
# Out:
# 2023-03-06 19:14:44,157 - BERTopic - Reduced dimensionality
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2023-03-06 19:54:47,784 - BERTopic - Clustered reduced embeddings

# %%
# !date
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Mon Mar  6 20:07:17 UTC 2023

# %%
topic_model_gpu.get_topic_freq().head()
# Out:
#    Topic    Count
# 0     -1  2376067
# 1      0    39821
# 2      1    36256
# 3      2    33925
# 4      3    26524

# %%
topic_model_gpu.visualize_topics()

# %%
hierarchical_topics = topic_model_gpu.hierarchical_topics(data[1:len(data)//4])
tree = topic_model_gpu.get_topic_tree(hierarchical_topics)
print(tree)
# Out:
# 100%|██████████| 1450/1450 [05:38<00:00,  4.28it/s]
# .
# ├─it_is_you_the_to
# │    ├─fiverr_use_domain_links_backlinks
# │    │    ├─fiverr_backlinks_pbn_pr_links
# │    │    │    ├─keyword_tool_niche_keywords_keyword research
# │    │    │    │    ├─niche_niches_the niche_niche is_your niche
# │    │    │    │    │    ├─■──micro_micro niche_niche_niche sites_niche site ── Topic: 662
# │    │    │    │    │    └─niche_niches_the niche_niche is_csv
# │    │    │    │    │         ├─■──niche_niches_the niche_niche is_csv ── Topic: 81
# │    │    │    │    │         └─■──niche_keywords_keyword_research_niche keyword ── Topic: 1007
# │    │    │    │    └─keyword_tool_keywords_keyword research_the keyword
# │    │    │    │         ├─keyword_density_keywords_keyword density_searches
# │    │    │    │         │    ├─competition_competitor_the competition_competitors_competition is
# │    │    │    │         │    │    ├─■──competition_competitor_competitors_the competition_your competitor ── Topic: 387
# │    │    │    │         │    │    └─■──competition_keyword_low competition_competitive_competition keyword ── Topic: 967
# │    │    │    │         │    └─keyword_density_keywords_keyword density_searches
# │    │    │    │         │         ├─keyword_searches_keywords_search volume_volume
# │    │    │    │         │         │    ├─■──searches_exact_search volume_volume_broad ── Topic: 327
# │    │    │    │         │         │    └─keywords_keyword_the keyword_the keywords_to rank
# │    │    │    │         │         │         ├─keywords_keyword_to rank_rank_the keyword
# │    │    │    │         │         │         │    ├─■──to rank_rank_rank for_keyword_keywords ── Topic: 682
# │    │    │    │         │         │         │    └─■──keywords_keyword_where to_review_the keywords ── Topic: 463
# │    │    │    │         │         │         └─■──keyword_keywords_the keyword_keyword thanks_keywords thanks ── Topic: 379
# │    │    │    │         │         └─■──density_keyword density_keyword_keyword stuffing_lsi ── Topic: 302
# │    │    │    │         └─tool_research bible_bible find_unlimited easy_quickly adsense
# │    │    │    │              ├─tool_tools_planner_keyword planner_this tool
# │    │    │    │              │    ├─■──planner_keyword planner_google keyword_keyword_planner is ── Topic: 538
# │    │    │    │              │    └─tool_tools_this tool_the tool_great tool
# │    │    │    │              │         ├─■──keyword tool_tool_keyword_google keyword_keyword research ── Topic: 429
# │    │    │    │              │         └─■──tool_tools_this tool_the tool_great tool ── Topic: 51
# │    │    │    │              └─research bible_bible find_unlimited easy_quickly adsense_keywords quickly
# │    │    │    │                   ├─■──keyword research_research_keyword_do keyword_research is ── Topic: 919
# │    │    │    │                   └─■──research bible_bible find_unlimited easy_quickly adsense_keywords quickly ── Topic: 396
# │    │    │    └─fiverr_backlinks_pbn_pr_links
# │    │    │         ├─alexa_panda_article_tier_links
# │    │    │         │    ├─article_articles_writing_writers_amr
# │    │    │         │    │    ├─amr_directories_directory_article_ezine
# │    │    │         │    │    │    ├─■──amr_amr is_with amr_of amr_for amr ── Topic: 518
# │    │    │         │    │    │    └─directories_directory_amr_article_ezine
# │    │    │         │    │    │         ├─■──directories_directory_amr_submission_directory submission ── Topic: 196
# │    │    │         │    │    │         └─■──ezine_article_directories_article directories_articles ── Topic: 343
# │    │    │         │    │    └─writers_writing_article_articles_writer
# │    │    │         │    │         ├─article_great article_articles_article thanks_the article
# │    │    │         │    │         │    ├─■──article_great article_article thanks_the article_articles ── Topic: 309
# │    │    │         │    │         │    └─■──articles_article_backlinks_backlink_the article ── Topic: 1387
# │    │    │         │    │         └─writers_writing_writer_articles_article
# │    │    │         │    │              ├─■──writers_writing_writer_articles_article ── Topic: 57
# │    │    │         │    │              └─■──words_length_article_articles_word ── Topic: 982
# │    │    │         │    └─alexa_panda_tier_links_spinner
# │    │    │         │         ├─alexa_panda_tier_links_spinner
# │    │    │         │         │    ├─panda_dance_penguin_sandbox_update
# │    │    │         │         │    │    ├─panda_panda update_the panda_update_panda smart
# │    │    │         │         │    │    │    ├─■──panda_panda smart_panda bot_bot network_smart browser ── Topic: 1092
# │    │    │         │         │    │    │    └─■──panda_panda update_the panda_update_google panda ── Topic: 118
# │    │    │         │         │    │    └─dance_sandbox_penguin_google dance_sandboxed
# │    │    │         │         │    │         ├─penguin_update_results_penguin update_updates
# │    │    │         │         │    │         │    ├─results_result_the results_your results_serps
# │    │    │         │         │    │         │    │    ├─■──experiment_experiments_this experiment_your experiment_the experiment ── Topic: 1406
# │    │    │         │         │    │         │    │    └─results_result_the results_your results_serps
# │    │    │         │         │    │         │    │         ├─results_result_the results_your results_how long
# │    │    │         │         │    │         │    │         │    ├─■──how long_days_weeks_months_it take ── Topic: 361
# │    │    │         │         │    │         │    │         │    └─■──results_result_the results_your results_the result ── Topic: 246
# │    │    │         │         │    │         │    │         └─■──serps_serp_the serps_my serps_in serps ── Topic: 781
# │    │    │         │         │    │         │    └─penguin_update_penguin update_updates_the penguin
# │    │    │         │         │    │         │         ├─penguin_update_penguin update_updates_the penguin
# │    │    │         │         │    │         │         │    ├─■──penguin_penguin update_the penguin_update_penguin is ── Topic: 262
# │    │    │         │         │    │         │         │    └─update_updates_the update_updated_any updates
# │    │    │         │         │    │         │         │         ├─■──my sites_sites_my site_site_sites are ── Topic: 383
# │    │    │         │         │    │         │         │         └─■──update_updates_the update_updated_any updates ── Topic: 214
# │    │    │         │         │    │         │         └─happened_happened to_to me_happens_drop
# │    │    │         │         │    │         │              ├─■──happened_happened to_to me_happens_it happens ── Topic: 650
# │    │    │         │         │    │         │              └─■──drop_dropped_drops_dropping_big drop ── Topic: 1398
# │    │    │         │         │    │         └─dance_sandbox_google dance_sandboxed_dancing
# │    │    │         │         │    │              ├─rankings_ranking_rank_ranked_my rankings
# │    │    │         │         │    │              │    ├─■──rank_to rank_ranking_rank my_can rank ── Topic: 1339
# │    │    │         │         │    │              │    └─rankings_ranking_rank_my rankings_ranked
# │    │    │         │         │    │              │         ├─■──rankings_ranking_rank_your rankings_to rank ── Topic: 163
# │    │    │         │         │    │              │         └─■──rankings_ranking_dropped_keywords_position ── Topic: 351
# │    │    │         │         │    │              └─dance_sandbox_google dance_sandboxed_the sandbox
# │    │    │         │         │    │                   ├─■──dance_google dance_dancing_the dance_the google ── Topic: 131
# │    │    │         │         │    │                   └─■──sandbox_sandboxed_the sandbox_get sandboxed_google sandbox ── Topic: 168
# │    │    │         │         │    └─alexa_tier_links_spinner_title
# │    │    │         │         │         ├─squidoo_lens_lenses_squidoo lens_your lens
# │    │    │         │         │         │    ├─■──lens_squidoo_lenses_squidoo lens_your lens ── Topic: 557
# │    │    │         │         │         │    └─■──squidoo_hubpages_with squidoo_squidoo and_squidoo is ── Topic: 798
# │    │    │         │         │         └─alexa_tier_links_spinner_title
# │    │    │         │         │              ├─tier_spinner_links_sitemap_web
# │    │    │         │         │              │    ├─tier_spinner_links_web_nofollow
# │    │    │         │         │              │    │    ├─tier_links_nofollow_web_anchor
# │    │    │         │         │              │    │    │    ├─kw_parasite_parasites_da_kws
# │    │    │         │         │              │    │    │    │    ├─da_metrics_tf_trust_metric
# │    │    │         │         │              │    │    │    │    │    ├─■──trust_to trust_can trust_trust anyone_don trust ── Topic: 970
# │    │    │         │         │              │    │    │    │    │    └─■──da_metrics_tf_metric_pa ── Topic: 349
# │    │    │         │         │              │    │    │    │    └─kw_parasite_parasites_kws_kwfinder
# │    │    │         │         │              │    │    │    │         ├─kw_parasite_parasites_kws_kwfinder
# │    │    │         │         │              │    │    │    │         │    ├─parasite_parasites_authority_the parasite_authority site
# │    │    │         │         │              │    │    │    │         │    │    ├─■──authority_authority site_an authority_authority sites_authority website ── Topic: 1066
# │    │    │         │         │              │    │    │    │         │    │    └─■──parasite_parasites_the parasite_parasite pages_rank ── Topic: 431
# │    │    │         │         │              │    │    │    │         │    └─kw_kws_kwfinder_kw research_the kw
# │    │    │         │         │              │    │    │    │         │         ├─■──kw_kws_kwfinder_kw research_the kw ── Topic: 239
# │    │    │         │         │              │    │    │    │         │         └─■──both_which one_do both_use both_difference ── Topic: 407
# │    │    │         │         │              │    │    │    │         └─■──build_build it_to build_build one_build your ── Topic: 1023
# │    │    │         │         │              │    │    │    └─tier_nofollow_links_web_anchor
# │    │    │         │         │              │    │    │         ├─wiki_wikipedia_wikis_wiki links_wikipedia is
# │    │    │         │         │              │    │    │         │    ├─■──wiki_wikis_wiki links_wiki sites_wiki poster ── Topic: 421
# │    │    │         │         │              │    │    │         │    └─■──wikipedia_wikipedia is_on wikipedia_wikipedia page_from wikipedia ── Topic: 560
# │    │    │         │         │              │    │    │         └─tier_nofollow_web_links_anchor
# │    │    │         │         │              │    │    │              ├─tier_nofollow_web_links_anchor
# │    │    │         │         │              │    │    │              │    ├─■──nofollow_nofollow links_the nofollow_rel_links ── Topic: 291
# │    │    │         │         │              │    │    │              │    └─tier_web_anchor_links_anchor text
# │    │    │         │         │              │    │    │              │         ├─■──anchor_anchor text_text_anchors_the anchor ── Topic: 148
# │    │    │         │         │              │    │    │              │         └─tier_web_links_0s_web2
# │    │    │         │         │              │    │    │              │              ├─■──link building_links_building_link_of links ── Topic: 38
# │    │    │         │         │              │    │    │              │              └─■──tier_web_0s_web2_web 0s ── Topic: 36
# │    │    │         │         │              │    │    │              └─linkwheel_wheel_linkwheels_wheels_link wheel
# │    │    │         │         │              │    │    │                   ├─■──linkwheel_wheel_linkwheels_link wheel_wheels ── Topic: 297
# │    │    │         │         │              │    │    │                   └─■──hubpages_hub_hubs_hubpage_your hub ── Topic: 1152
# │    │    │         │         │              │    │    └─spinner_spin_duplicate_duplicate content_spinning
# │    │    │         │         │              │    │         ├─duplicate_duplicate content_copyscape_content_plagiarism
# │    │    │         │         │              │    │         │    ├─duplicate_duplicate content_copyscape_content_plagiarism
# │    │    │         │         │              │    │         │    │    ├─■──canonical_canonical tag_rel canonical_the canonical_canonical tags ── Topic: 1437
# │    │    │         │         │              │    │         │    │    └─duplicate_duplicate content_copyscape_content_plagiarism
# │    │    │         │         │              │    │         │    │         ├─■──copyscape_plagiarism_plagiarism checker_checker_copyscape is ── Topic: 295
# │    │    │         │         │              │    │         │    │         └─duplicate_duplicate content_content_unique_unique content
# │    │    │         │         │              │    │         │    │              ├─■──duplicate_duplicate content_content_unique_unique content ── Topic: 142
# │    │    │         │         │              │    │         │    │              └─■──quality content_content_quality_content is_of content ── Topic: 1085
# │    │    │         │         │              │    │         │    └─■──quantity_quality_quality over_over quantity_quality is ── Topic: 882
# │    │    │         │         │              │    │         └─spinner_spin_spinning_tbs_best spinner
# │    │    │         │         │              │    │              ├─■──spinner_spin_spinning_best spinner_tbs ── Topic: 58
# │    │    │         │         │              │    │              └─■──tbs_tbs is_for tbs_tbs for_use tbs ── Topic: 1198
# │    │    │         │         │              │    └─sitemap_penalty_disavow_xml_webmaster
# │    │    │         │         │              │         ├─sitemap_xml_the sitemap_sitemaps_webmaster
# │    │    │         │         │              │         │    ├─■──sitemap_xml_the sitemap_sitemaps_your sitemap ── Topic: 211
# │    │    │         │         │              │         │    └─■──webmaster_webmaster tools_google webmaster_webmaster tool_tools ── Topic: 1315
# │    │    │         │         │              │         └─penalty_disavow_gwt_penalized_disavow tool
# │    │    │         │         │              │              ├─penalty_disavow_disavow tool_penalized_the disavow
# │    │    │         │         │              │              │    ├─■──disavow_disavow tool_the disavow_links_unnatural ── Topic: 393
# │    │    │         │         │              │              │    └─■──penalty_penalized_penalties_the penalty_manual penalty ── Topic: 314
# │    │    │         │         │              │              └─■──gwt_wmt_in gwt_in wmt_gwt account ── Topic: 906
# │    │    │         │         │              └─alexa_title_meta_bounce_bounce rate
# │    │    │         │         │                   ├─alexa_bounce_bounce rate_analytics_alexa rank
# │    │    │         │         │                   │    ├─alexa_bounce_bounce rate_analytics_alexa rank
# │    │    │         │         │                   │    │    ├─alexa_bounce_bounce rate_alexa rank_analytics
# │    │    │         │         │                   │    │    │    ├─■──stats_statistics_stat_my stats_statistics are ── Topic: 908
# │    │    │         │         │                   │    │    │    └─alexa_bounce_bounce rate_alexa rank_analytics
# │    │    │         │         │                   │    │    │         ├─bounce_bounce rate_analytics_rate_google analytics
# │    │    │         │         │                   │    │    │         │    ├─■──bounce_bounce rate_rate_the bounce_rate is ── Topic: 299
# │    │    │         │         │                   │    │    │         │    └─■──analytics_google analytics_piwik_ga_analytics is ── Topic: 281
# │    │    │         │         │                   │    │    │         └─■──alexa_alexa rank_alexa ranking_the alexa_rank ── Topic: 103
# │    │    │         │         │                   │    │    └─cpc_clicks_uv_the cpc_per click
# │    │    │         │         │                   │    │         ├─uv_visitors_visits_uvs_uv day
# │    │    │         │         │                   │    │         │    ├─■──uv_uvs_uv day_uv per_many uv ── Topic: 1018
# │    │    │         │         │                   │    │         │    └─■──visitors_visits_unique visitors_visitor_many visitors ── Topic: 674
# │    │    │         │         │                   │    │         └─cpc_clicks_the cpc_cpc is_per click
# │    │    │         │         │                   │    │              ├─■──clicks_click_per click_many clicks_per ── Topic: 374
# │    │    │         │         │                   │    │              └─■──cpc_the cpc_cpc is_your cpc_per click ── Topic: 499
# │    │    │         │         │                   │    └─speed_mbps_cache_load_slow
# │    │    │         │         │                   │         ├─■──speed_mbps_comcast_connection_internet ── Topic: 153
# │    │    │         │         │                   │         └─speed_cache_load_loading_slow
# │    │    │         │         │                   │              ├─■──slow_speed_fast_slow for_faster ── Topic: 630
# │    │    │         │         │                   │              └─■──speed_cache_load_loading_page speed ── Topic: 260
# │    │    │         │         │                   └─title_meta_tags_tag_h1
# │    │    │         │         │                        ├─title_meta_tags_tag_h1
# │    │    │         │         │                        │    ├─■──clickbait_bait_click bait_clickbait title_baiting ── Topic: 917
# │    │    │         │         │                        │    └─title_meta_tags_tag_h1
# │    │    │         │         │                        │         ├─■──title_the title_misleading_thread title_misleading title ── Topic: 532
# │    │    │         │         │                        │         └─■──meta_title_tags_tag_h1 ── Topic: 71
# │    │    │         │         │                        └─tail_chase_long tail_tail but_chase tail
# │    │    │         │         │                             ├─■──tail_long tail_tail keywords_tail keyword_long ── Topic: 565
# │    │    │         │         │                             └─■──chase_tail_chase tail_do chase_always chase ── Topic: 864
# │    │    │         │         └─profile_profiles_profile links_the profile_your profile
# │    │    │         │              ├─profile_profiles_profile links_the profile_links
# │    │    │         │              │    ├─■──profiles_profile_removed removed_the profile_the profiles ── Topic: 1144
# │    │    │         │              │    └─■──profile_profile links_profiles_links_indexed ── Topic: 552
# │    │    │         │              └─■──profile_profile picture_profile pic_picture_pic ── Topic: 1233
# │    │    │         └─fiverr_pbn_gig_backlinks_domain
# │    │    │              ├─fiverr_gig_gigs_backlinks_pr
# │    │    │              │    ├─fiverr_gig_gigs_pr_backlinks
# │    │    │              │    │    ├─fiverr_gig_gigs_on fiverr_fiverr is
# │    │    │              │    │    │    ├─■──fiverr_gig_gigs_on fiverr_fiverr is ── Topic: 3
# │    │    │              │    │    │    └─■──fiverr_on fiverr_backlinks_gigs_from fiverr ── Topic: 1308
# │    │    │              │    │    └─pr_backlinks_backlink_high pr_pr is
# │    │    │              │    │         ├─backlinks_backlink_of backlinks_backlinking_the backlinks
# │    │    │              │    │         │    ├─backlinks_backlink_of backlinks_backlinking_the backlinks
# │    │    │              │    │         │    │    ├─■──backlinks_blog_blogs_backlink_backlinks from ── Topic: 1036
# │    │    │              │    │         │    │    └─■──backlinks_backlink_of backlinks_backlinking_the backlinks ── Topic: 7
# │    │    │              │    │         │    └─■──backlinks_domain_domains_referring domains_referring ── Topic: 1072
# │    │    │              │    │         └─pr_high pr_pr is_the pr_pr3
# │    │    │              │    │              ├─■──pr_domain_fake pr_the pr_pr domains ── Topic: 581
# │    │    │              │    │              └─■──pr_high pr_pr is_the pr_pr3 ── Topic: 32
# │    │    │              │    └─indexed_index_indexing_get indexed_to index
# │    │    │              │         ├─indexed_index_indexing_get indexed_to index
# │    │    │              │         │    ├─■──indexed_backlinks_index_indexing_backlink ── Topic: 332
# │    │    │              │         │    └─■──indexed_index_indexing_get indexed_to index ── Topic: 25
# │    │    │              │         └─■──indexed_web2_web_index_0s ── Topic: 1395
# │    │    │              └─pbn_emd_domain_domains_expired
# │    │    │                   ├─pbn_expired_pbns_domains_expired domains
# │    │    │                   │    ├─■──pbn_pbns_your pbn_the pbn_pbn links ── Topic: 26
# │    │    │                   │    └─expired_expired domains_expired domain_domains_domain
# │    │    │                   │         ├─■──expired_expired domains_pbn_domains_expired domain ── Topic: 1191
# │    │    │                   │         └─■──expired_expired domains_expired domain_domains_domain ── Topic: 193
# │    │    │                   └─emd_domain_domains_the domain_domain name
# │    │    │                        ├─emd_domain_domains_the domain_domain name
# │    │    │                        │    ├─■──subdomains_subdomain_sub_sub domain_sub domains ── Topic: 497
# │    │    │                        │    └─emd_domain_domains_the domain_domain name
# │    │    │                        │         ├─■──aged_aged domain_age_domain age_aged domains ── Topic: 1203
# │    │    │                        │         └─emd_domain_domains_the domain_domain name
# │    │    │                        │              ├─domain_domains_the domain_domain name_name
# │    │    │                        │              │    ├─■──hyphens_hyphen_dashes_hyphenated_dash ── Topic: 492
# │    │    │                        │              │    └─domain_domains_the domain_domain name_name
# │    │    │                        │              │         ├─domain_domains_the domain_domain name_name
# │    │    │                        │              │         │    ├─■──domain_domains_the domain_domain name_brandable ── Topic: 23
# │    │    │                        │              │         │    └─■──domain_domain name_the domain_keyword_exact match ── Topic: 199
# │    │    │                        │              │         └─■──tld_org_net_info_tlds ── Topic: 251
# │    │    │                        │              └─■──emd_an emd_emds_the emd_emd is ── Topic: 84
# │    │    │                        └─■──parking_parked_domain parking_parked domains_parked domain ── Topic: 660
# │    │    └─captcha_scrapebox_use_windows_hat
# │    │         ├─scrapebox_proxies_emails_email_vps
# │    │         │    ├─scrapebox_emails_email_images_gsa
# │    │         │    │    ├─emails_scrapebox_email_images_image
# │    │         │    │    │    ├─scrapebox_images_image_comments_comment
# │    │         │    │    │    │    ├─images_image_scrapebox_the image_the images
# │    │         │    │    │    │    │    ├─images_image_the image_the images_alt
# │    │         │    │    │    │    │    │    ├─■──pics_pic_pics or_picture_pictures ── Topic: 406
# │    │         │    │    │    │    │    │    └─images_image_the image_the images_alt
# │    │         │    │    │    │    │    │         ├─■──images_image_the image_the images_alt ── Topic: 20
# │    │         │    │    │    │    │    │         └─■──images_image scraper_image_scraper_scrape ── Topic: 1298
# │    │         │    │    │    │    │    └─scrapebox_scrape_scrapebox is_scraper_scraping
# │    │         │    │    │    │    │         ├─scrape_scraper_article scraper_to scrape_scrapebox
# │    │         │    │    │    │    │         │    ├─■──article scraper_scraper_article_scrape_articles ── Topic: 1250
# │    │         │    │    │    │    │         │    └─■──scrape_scraper_keywords_keyword scraper_scrapebox ── Topic: 1213
# │    │         │    │    │    │    │         └─scrapebox_scrapebox is_scrape_scraper_buy scrapebox
# │    │         │    │    │    │    │              ├─■──scrapebox_scrapebox is_scrape_scraper_buy scrapebox ── Topic: 29
# │    │         │    │    │    │    │              └─■──scrapebox_backlinks_backlink_with scrapebox_use scrapebox ── Topic: 783
# │    │         │    │    │    │    └─comments_comment_commenting_blogs_blog
# │    │         │    │    │    │         ├─comments_comment_commenting_blogs_scrapebox
# │    │         │    │    │    │         │    ├─■──comment_comments_youtube_youtube comment_bot ── Topic: 645
# │    │         │    │    │    │         │    └─comments_comment_commenting_blogs_scrapebox
# │    │         │    │    │    │         │         ├─■──comments_comment_commenting_blog_the comment ── Topic: 80
# │    │         │    │    │    │         │         └─■──scrapebox_comments_blogs_comment_blog ── Topic: 226
# │    │         │    │    │    │         └─■──akismet_by akismet_comments_akismet is_comment ── Topic: 1355
# │    │         │    │    │    └─emails_email_smtp_gmail_mail
# │    │         │    │    │         ├─emails_email_smtp_gmail_mail
# │    │         │    │    │         │    ├─■──emails_email_smtp_gmail_mailchimp ── Topic: 18
# │    │         │    │    │         │    └─■──email_emails_email marketing_list_email list ── Topic: 73
# │    │         │    │    │         └─emails_email_scrape_emails from_extract
# │    │         │    │    │              ├─■──emails_email_scrape_extractor_email extractor ── Topic: 267
# │    │         │    │    │              └─■──facebook_emails_from facebook_emails from_extract ── Topic: 1057
# │    │         │    │    └─gsa_ser_gsa ser_gsa is_ranker
# │    │         │    │         ├─■──gsa_scrapebox_ser_gsa ser_scrapebox and ── Topic: 625
# │    │         │    │         └─gsa_ser_gsa ser_tier_gsa is
# │    │         │    │              ├─■──gsa_ser_gsa ser_gsa is_for gsa ── Topic: 273
# │    │         │    │              └─■──gsa_tier_ranker_ser_gsa ser ── Topic: 212
# │    │         │    └─proxies_xrumer_vps_proxy_vpn
# │    │         │         ├─xrumer_vps_xrumer is_the vps_scrapebox
# │    │         │         │    ├─vps_the vps_windows_vps and_windows vps
# │    │         │         │    │    ├─■──vps_seo tools_tools_seo vps_vps with ── Topic: 1186
# │    │         │         │    │    └─vps_the vps_windows_vps and_windows vps
# │    │         │         │    │         ├─■──vps_the vps_windows vps_windows_vps is ── Topic: 95
# │    │         │         │    │         └─■──vps_scrapebox_run scrapebox_scrapebox on_ram ── Topic: 700
# │    │         │         │    └─xrumer_xrumer is_with xrumer_xrumer and_blast
# │    │         │         │         ├─■──xrumer_vps_run xrumer_xrumer on_with xrumer ── Topic: 1068
# │    │         │         │         └─xrumer_xrumer is_with xrumer_blast_xrumer and
# │    │         │         │              ├─xrumer_xrumer is_with xrumer_blast_xrumer and
# │    │         │         │              │    ├─■──xrumer_blast_with xrumer_xrumer blast_profiles ── Topic: 206
# │    │         │         │              │    └─■──xrumer_xrumer is_buy xrumer_of xrumer_for xrumer ── Topic: 172
# │    │         │         │              └─■──xrumer_scrapebox_xrumer and_scrapebox and_and scrapebox ── Topic: 693
# │    │         │         └─proxies_proxy_vpn_ip_private
# │    │         │              ├─proxies_proxy_vpn_private_private proxies
# │    │         │              │    ├─vpn_the vpn_use vpn_ip_vpns
# │    │         │              │    │    ├─■──vpn_use vpn_the vpn_ip_10292012 21 ── Topic: 189
# │    │         │              │    │    └─■──vpn_proxy_proxies_hma_or vpn ── Topic: 964
# │    │         │              │    └─proxies_proxy_private proxies_private_proxies and
# │    │         │              │         ├─proxies_proxy_private proxies_private_proxies and
# │    │         │              │         │    ├─■──proxies_scrapebox_proxy_public proxies_scraping ── Topic: 171
# │    │         │              │         │    └─■──proxies_proxy_need proxies_proxies and_private proxies ── Topic: 31
# │    │         │              │         └─■──proxy_proxies_accounts_per proxy_accounts per ── Topic: 675
# │    │         │              └─ip_ips_ip address_same ip_hosting
# │    │         │                   ├─ip_ips_ip address_my ip_address
# │    │         │                   │    ├─■──ip_same ip_accounts_ips_account ── Topic: 1044
# │    │         │                   │    └─■──ip_ip address_ips_my ip_your ip ── Topic: 252
# │    │         │                   └─■──ip_hosting_seo hosting_class_ips ── Topic: 550
# │    │         └─captcha_hat_windows_software_black
# │    │              ├─captcha_windows_software_mac_301
# │    │              │    ├─captcha_301_app_redirect_software
# │    │              │    │    ├─chrome_firefox_browser_cookie_flash
# │    │              │    │    │    ├─cookie_cookie stuffing_stuffing_cookies_the cookie
# │    │              │    │    │    │    ├─■──cookie_cookies_day cookie_the cookie_cookie is ── Topic: 1094
# │    │              │    │    │    │    └─■──cookie_cookie stuffing_stuffing_cookies_the cookie ── Topic: 290
# │    │              │    │    │    └─chrome_firefox_browser_flash_adblock
# │    │              │    │    │         ├─chrome_firefox_browser_adblock_ff
# │    │              │    │    │         │    ├─adblock_popup_pop_adblocker_ads
# │    │              │    │    │         │    │    ├─■──popup_pop_pop up_br_exit ── Topic: 531
# │    │              │    │    │         │    │    └─■──adblock_adblocker_ads_block_ad ── Topic: 378
# │    │              │    │    │         │    └─chrome_firefox_browser_ff_opera
# │    │              │    │    │         │         ├─chrome_firefox_browser_ff_opera
# │    │              │    │    │         │         │    ├─■──cookies_incognito_bad gateway_cookies and_browser ── Topic: 615
# │    │              │    │    │         │         │    └─■──chrome_firefox_browser_ff_opera ── Topic: 39
# │    │              │    │    │         │         └─■──fingerprint_browser_fingerprints_incogniton_fingerprinting ── Topic: 1353
# │    │              │    │    │         └─flash_cookies_flash cookies_swf_the flash
# │    │              │    │    │              ├─■──cookies_flash cookies_flash_ccleaner_delete ── Topic: 1187
# │    │              │    │    │              └─■──flash_swf_the flash_flash player_adobe ── Topic: 449
# │    │              │    │    └─captcha_301_app_redirect_captchas
# │    │              │    │         ├─captcha_301_app_redirect_captchas
# │    │              │    │         │    ├─down_server_down for_is down_was down
# │    │              │    │         │    │    ├─down_down for_is down_was down_back up
# │    │              │    │         │    │    │    ├─■──is down_down_down for_site is_was down ── Topic: 777
# │    │              │    │         │    │    │    └─■──down for_down_back up_was down_it back ── Topic: 375
# │    │              │    │         │    │    └─server_servers_the server_dedicated server_dedicated
# │    │              │    │         │    │         ├─■──server_the server_servers_server is_servers are ── Topic: 816
# │    │              │    │         │    │         └─■──server_dedicated server_dedicated_servers_dedicated servers ── Topic: 979
# │    │              │    │         │    └─captcha_301_app_redirect_captchas
# │    │              │    │         │         ├─301_redirect_theme_locker_rss
# │    │              │    │         │         │    ├─301_redirect_301 redirect_htaccess_domain
# │    │              │    │         │         │    │    ├─error_404_database_same error_errors
# │    │              │    │         │         │    │    │    ├─error_database_same error_the error_errors
# │    │              │    │         │         │    │    │    │    ├─■──database_the database_mysql_error_database error ── Topic: 712
# │    │              │    │         │         │    │    │    │    └─■──error_same error_the error_errors_this error ── Topic: 588
# │    │              │    │         │         │    │    │    └─■──404_404 error_not found_error_404 page ── Topic: 1004
# │    │              │    │         │         │    │    └─301_redirect_301 redirect_htaccess_domain
# │    │              │    │         │         │    │         ├─■──htaccess_htaccess file_the htaccess_file_rewritecond ── Topic: 832
# │    │              │    │         │         │    │         └─301_redirect_301 redirect_domain_redirects
# │    │              │    │         │         │    │              ├─■──non www_www_the www_www and_rewriterule ── Topic: 432
# │    │              │    │         │         │    │              └─■──301_redirect_301 redirect_new domain_the 301 ── Topic: 61
# │    │              │    │         │         │    └─theme_locker_rss_script_wordpress
# │    │              │    │         │         │         ├─locker_rss_script_content locker_ping
# │    │              │    │         │         │         │    ├─locker_rss_content locker_ping_autoblog
# │    │              │    │         │         │         │    │    ├─locker_content locker_landing_referrer_locking
# │    │              │    │         │         │         │    │    │    ├─locker_content locker_landing_locking_content locking
# │    │              │    │         │         │         │    │    │    │    ├─■──lp_the lp_lps_your lp_ogads ── Topic: 1041
# │    │              │    │         │         │         │    │    │    │    └─locker_content locker_landing_locking_content locking
# │    │              │    │         │         │         │    │    │    │         ├─■──landing_landing page_landing pages_page_the landing ── Topic: 270
# │    │              │    │         │         │         │    │    │    │         └─■──locker_content locker_locking_content locking_lock ── Topic: 82
# │    │              │    │         │         │         │    │    │    └─referrer_iframe_referer_the referrer_shortener
# │    │              │    │         │         │         │    │    │         ├─referrer_iframe_referer_the referrer_blank
# │    │              │    │         │         │         │    │    │         │    ├─■──iframe_the iframe_iframes_an iframe_iframing ── Topic: 365
# │    │              │    │         │         │         │    │    │         │    └─■──referrer_the referrer_referer_blank_the referer ── Topic: 283
# │    │              │    │         │         │         │    │    │         └─■──shortener_url_url shortener_shorteners_ly ── Topic: 312
# │    │              │    │         │         │         │    │    └─rss_ping_autoblog_autoblogs_feeds
# │    │              │    │         │         │         │    │         ├─rss_ping_autoblog_autoblogs_feeds
# │    │              │    │         │         │         │    │         │    ├─rss_ping_feeds_feed_rss feed
# │    │              │    │         │         │         │    │         │    │    ├─■──ping_pinging_to ping_pings_pingfarm ── Topic: 166
# │    │              │    │         │         │         │    │         │    │    └─■──rss_feeds_feed_rss feed_rss feeds ── Topic: 180
# │    │              │    │         │         │         │    │         │    └─■──autoblog_autoblogs_autoblogging_an autoblog_autoblogger ── Topic: 141
# │    │              │    │         │         │         │    │         └─silo_widget_silo structure_silos_category
# │    │              │    │         │         │         │    │              ├─■──silo_silo structure_silos_structure_category ── Topic: 647
# │    │              │    │         │         │         │    │              └─■──widget_widgets_sidebar_the widget_the sidebar ── Topic: 974
# │    │              │    │         │         │         │    └─script_code_the script_php_code http
# │    │              │    │         │         │         │         ├─code_php_code http_the code_phpbuilt
# │    │              │    │         │         │         │         │    ├─■──code_code http_the code_coding_coder ── Topic: 85
# │    │              │    │         │         │         │         │    └─■──php_phpbuilt_php script_script_php and ── Topic: 244
# │    │              │    │         │         │         │         └─script_the script_this script_scripts_script is
# │    │              │    │         │         │         │              ├─■──script_the script_this script_scripts_script is ── Topic: 110
# │    │              │    │         │         │         │              └─■──geoip_maxmind_geo_redirect_country ── Topic: 1243
# │    │              │    │         │         │         └─theme_wordpress_joomla_themes_shopify
# │    │              │    │         │         │              ├─theme_wordpress_joomla_themes_shopify
# │    │              │    │         │         │              │    ├─■──theme_themes_themeforest_the theme_wordpress theme ── Topic: 76
# │    │              │    │         │         │              │    └─joomla_shopify_wordpress_plugin_cms
# │    │              │    │         │         │              │         ├─■──shopify_woocommerce_ecommerce_store_magento ── Topic: 133
# │    │              │    │         │         │              │         └─joomla_wordpress_plugin_cms_plugins
# │    │              │    │         │         │              │              ├─■──joomla_wordpress_cms_drupal_wp ── Topic: 129
# │    │              │    │         │         │              │              └─■──plugin_plugins_the plugin_this plugin_wp ── Topic: 157
# │    │              │    │         │         │              └─template_templates_dreamweaver_the template_editor
# │    │              │    │         │         │                   ├─■──template_templates_the template_the templates_templatemonster ── Topic: 376
# │    │              │    │         │         │                   └─■──dreamweaver_editor_notepad_dreamweaver is_table ── Topic: 810
# │    │              │    │         │         └─captcha_app_captchas_software_senuke
# │    │              │    │         │              ├─captcha_app_captchas_software_senuke
# │    │              │    │         │              │    ├─captcha_captchas_recaptcha_captcha sniper_sniper
# │    │              │    │         │              │    │    ├─■──1linklist com_1captchas_1captchas com_ocr 4780_to warp ── Topic: 1117
# │    │              │    │         │              │    │    └─captcha_captchas_recaptcha_captcha sniper_sniper
# │    │              │    │         │              │    │         ├─■──captcha_captchas_recaptcha_captcha sniper_sniper ── Topic: 15
# │    │              │    │         │              │    │         └─■──xrumer_captcha_xevil_recaptcha_improved ── Topic: 1214
# │    │              │    │         │              │    └─app_senuke_software_cloaking_license
# │    │              │    │         │              │         ├─license_the license_licenses_license key_licence
# │    │              │    │         │              │         │    ├─■──license_the license_license key_licenses_my license ── Topic: 162
# │    │              │    │         │              │         │    └─■──license_computers_pc_machines_can install ── Topic: 971
# │    │              │    │         │              │         └─app_senuke_cloaking_software_apps
# │    │              │    │         │              │              ├─zennoposter_ubot_zenno_zennolab_templates
# │    │              │    │         │              │              │    ├─■──ubot_ubot studio_studio_ubot is_with ubot ── Topic: 1181
# │    │              │    │         │              │              │    └─■──zennoposter_zenno_ubot_zennolab_templates ── Topic: 230
# │    │              │    │         │              │              └─app_senuke_cloaking_apps_software
# │    │              │    │         │              │                   ├─app_senuke_apps_software_android
# │    │              │    │         │              │                   │    ├─senuke_software_crack_cracked_the software
# │    │              │    │         │              │                   │    │    ├─■──bmd_bmd is_with bmd_for bmd_of bmd ── Topic: 661
# │    │              │    │         │              │                   │    │    └─senuke_software_crack_cracked_the software
# │    │              │    │         │              │                   │    │         ├─■──senuke_senukex_senuke is_ud_of senuke ── Topic: 122
# │    │              │    │         │              │                   │    │         └─software_crack_cracked_the software_this software
# │    │              │    │         │              │                   │    │              ├─■──software_the software_this software_program_of software ── Topic: 60
# │    │              │    │         │              │                   │    │              └─■──crack_cracked_cracked version_the crack_version ── Topic: 201
# │    │              │    │         │              │                   │    └─app_apps_android_the app_outsource
# │    │              │    │         │              │                   │         ├─outsource_outsourcing_to outsource_automation_automate
# │    │              │    │         │              │                   │         │    ├─■──automation_automate_to automate_manual_automated ── Topic: 276
# │    │              │    │         │              │                   │         │    └─■──outsource_outsourcing_to outsource_outsource it_outsourced ── Topic: 228
# │    │              │    │         │              │                   │         └─app_apps_android_the app_ios
# │    │              │    │         │              │                   │              ├─■──procrastination_procrastinator_procrastinate_procrastinating_procrastination is ── Topic: 936
# │    │              │    │         │              │                   │              └─app_apps_android_the app_ios
# │    │              │    │         │              │                   │                   ├─■──notepad_evernote_notes_tasks_trello ── Topic: 325
# │    │              │    │         │              │                   │                   └─■──app_apps_android_the app_ios ── Topic: 66
# │    │              │    │         │              │                   └─cloaking_cloaker_cloak_ticket_support
# │    │              │    │         │              │                        ├─cloaking_cloaker_cloak_campaign_campaigns
# │    │              │    │         │              │                        │    ├─cloaking_cloaker_cloak_campaign_campaigns
# │    │              │    │         │              │                        │    │    ├─cloaking_cloaker_cloak_campaign_campaigns
# │    │              │    │         │              │                        │    │    │    ├─■──cloaking_cloaker_cloak_cloakers_cloaked ── Topic: 115
# │    │              │    │         │              │                        │    │    │    └─■──campaign_campaigns_the campaign_my campaign_your campaign ── Topic: 415
# │    │              │    │         │              │                        │    │    └─■──setup_set_to set_set it_set up ── Topic: 886
# │    │              │    │         │              │                        │    └─■──settings_addmefast_addon_default_addons ── Topic: 789
# │    │              │    │         │              │                        └─ticket_refund_support_problem_tickets
# │    │              │    │         │              │                             ├─ticket_support_problem_tickets_same problem
# │    │              │    │         │              │                             │    ├─■──same problem_problem_fixed_solution_fix ── Topic: 91
# │    │              │    │         │              │                             │    └─■──ticket_support_tickets_contact_the support ── Topic: 113
# │    │              │    │         │              │                             └─■──refund_refunds_the refund_for refund_get refund ── Topic: 411
# │    │              │    │         │              └─method_this method_the method_saturated_twist
# │    │              │    │         │                   ├─working_works_not working_it works_worked
# │    │              │    │         │                   │    ├─■──the link_link is_link_not working_link not ── Topic: 930
# │    │              │    │         │                   │    └─works_working_it works_worked_not working
# │    │              │    │         │                   │         ├─■──works_working_it works_worked_tried it ── Topic: 139
# │    │              │    │         │                   │         └─■──fine for_working for_works for_working fine_working ── Topic: 247
# │    │              │    │         │                   └─method_this method_the method_saturated_twist
# │    │              │    │         │                        ├─method_this method_method thanks_the method_twist
# │    │              │    │         │                        │    ├─■──twist_twists_own twist_method_to twist ── Topic: 555
# │    │              │    │         │                        │    └─■──method_this method_method thanks_the method_nice method ── Topic: 40
# │    │              │    │         │                        └─■──saturated_get saturated_saturation_is saturated_method ── Topic: 578
# │    │              │    │         └─torrent_download_torrents_mediafire_watermark
# │    │              │    │              ├─torrent_download_torrents_mediafire_upload
# │    │              │    │              │    ├─torrent_torrents_mediafire_upload_xvideos
# │    │              │    │              │    │    ├─torrent_torrents_xvideos_warez_upload
# │    │              │    │              │    │    │    ├─■──xvideos_on xvideos_xvideo_upload_videos ── Topic: 772
# │    │              │    │              │    │    │    └─torrent_torrents_warez_torrent sites_the torrent
# │    │              │    │              │    │    │         ├─warez_warez forum_not warez_forum this_upload
# │    │              │    │              │    │    │         │    ├─■──warez_warez forum_not warez_forum this_downloads ── Topic: 614
# │    │              │    │              │    │    │         │    └─■──upload_uploading_to upload_remote upload_remote ── Topic: 1096
# │    │              │    │              │    │    │         └─■──torrent_torrents_torrent sites_the torrent_torrent site ── Topic: 140
# │    │              │    │              │    │    └─mediafire_rapidshare_mediafire com_www mediafire_zip
# │    │              │    │              │    │         ├─rapidshare_zip_file_reupload_winrar
# │    │              │    │              │    │         │    ├─■──zip_reupload_file_winrar_ziplack ── Topic: 585
# │    │              │    │              │    │         │    └─■──rapidshare_rapidshare is_mediafire_on rapidshare_rapidshare com ── Topic: 1284
# │    │              │    │              │    │         └─■──mediafire_mediafire com_www mediafire_to mediafire_mediafire link ── Topic: 514
# │    │              │    │              │    └─download_the download_download link_download section_to download
# │    │              │    │              │         ├─■──download_the download_download link_download section_downloads ── Topic: 158
# │    │              │    │              │         └─■──download_to download_video_downloader_videos ── Topic: 1272
# │    │              │    │              └─watermark_the watermark_watermarking_watermarks_to watermark
# │    │              │    │                   ├─■──watermark_video_watermarking_videos_to watermark ── Topic: 1049
# │    │              │    │                   └─■──watermark_the watermark_watermarks_watermarking_images ── Topic: 1071
# │    │              │    └─windows_mac_laptop_pc_virus
# │    │              │         ├─windows_mac_virus_password_pc
# │    │              │         │    ├─virus_password_hacked_antivirus_malware
# │    │              │         │    │    ├─virus_password_hacked_antivirus_malware
# │    │              │         │    │    │    ├─virus_antivirus_kaspersky_malware_scan
# │    │              │         │    │    │    │    ├─■──ccleaner_use ccleaner_ccleaner is_glary_msconfig ── Topic: 1312
# │    │              │         │    │    │    │    └─virus_antivirus_kaspersky_malware_scan
# │    │              │         │    │    │    │         ├─■──virus_antivirus_kaspersky_malware_avast ── Topic: 22
# │    │              │         │    │    │    │         └─■──keylogger_keyloggers_keyscrambler_keystrokes_key logger ── Topic: 935
# │    │              │         │    │    │    └─password_hacked_passwords_login_hacking
# ...
#      │    │         │    │              │              │         │    │              │         │         │                        ├─organic_organic traffic_sit_post opportunity_traffic sit
#      │    │         │    │              │              │         │    │              │         │         │                        │    ├─■──sit_the sit_my sit_your sit_sit thanks ── Topic: 727
#      │    │         │    │              │              │         │    │              │         │         │                        │    └─organic_organic traffic_post opportunity_traffic sit_opportunity on
#      │    │         │    │              │              │         │    │              │         │         │                        │         ├─■──post opportunity_traffic sit_opportunity on_start guest_services start ── Topic: 931
#      │    │         │    │              │              │         │    │              │         │         │                        │         └─■──organic_organic traffic_traffic_organic search_traffic is ── Topic: 467
#      │    │         │    │              │              │         │    │              │         │         │                        └─outreach links_outreach_of outreach_grail of_holy grail
#      │    │         │    │              │              │         │    │              │         │         │                             ├─■──outreach_samples outreach_content lowest_lowest charge_from webmast ── Topic: 1286
#      │    │         │    │              │              │         │    │              │         │         │                             └─■──of outreach_grail of_holy grail_grail_the holy ── Topic: 709
#      │    │         │    │              │              │         │    │              │         │         └─interest_interest interest_very interest_also interest_interest am
#      │    │         │    │              │              │         │    │              │         │              ├─■──interest_very interest_also interest_interest am_am interest ── Topic: 800
#      │    │         │    │              │              │         │    │              │         │              └─■──interest interest_interest_interest very_very interest_something interest ── Topic: 1125
#      │    │         │    │              │              │         │    │              │         └─sam_ceosam_ceo_ceo sam_sam hunt0710
#      │    │         │    │              │              │         │    │              │              ├─■──ceosam_ceo_ceo sam_sam_thanks ceosam ── Topic: 286
#      │    │         │    │              │              │         │    │              │              └─sam_hunt0710_sam hunt0710_the sam_thanks sam
#      │    │         │    │              │              │         │    │              │                   ├─■──sam_the sam_samlewis_aka sam_sam is ── Topic: 704
#      │    │         │    │              │              │         │    │              │                   └─■──hunt0710_sam hunt0710_sam_thanks sam_hunt0710 thanks ── Topic: 1253
#      │    │         │    │              │              │         │    │              └─tapatalk_using tapatalk_sent from_from my_my gt
#      │    │         │    │              │              │         │    │                   ├─■──tapatalk_using tapatalk_sent from_from my_sent ── Topic: 437
#      │    │         │    │              │              │         │    │                   └─■──using tapatalk_tapatalk_sent from_my gt_gt ── Topic: 680
#      │    │         │    │              │              │         │    └─bump_bump bump_bumping_old thread_bump for
#      │    │         │    │              │              │         │         ├─■──old thread_bumping_bump_old_thread ── Topic: 338
#      │    │         │    │              │              │         │         └─bump_bump bump_bump for_bumping_bump anyone
#      │    │         │    │              │              │         │              ├─■──bump_bump for_bumping_bump bump_bump anyone ── Topic: 147
#      │    │         │    │              │              │         │              └─■──bump bump_bump_bump bumpty_bumpty_bumpty bump ── Topic: 274
#      │    │         │    │              │              │         └─edited_last edited_last_2011_2012
#      │    │         │    │              │              │              ├─edited_last edited_last_2012_2011
#      │    │         │    │              │              │              │    ├─■──delete last_delete_deleted last_last edited_edited ── Topic: 688
#      │    │         │    │              │              │              │    └─■──edited_last edited_last_2012_2011 ── Topic: 86
#      │    │         │    │              │              │              └─■──double post_post last_double_2010 double_edited ── Topic: 998
#      │    │         │    │              │              └─voted_vote_thanks voted_votes_voted for
#      │    │         │    │              │                   ├─voted_vote_votes_thanks voted_voted for
#      │    │         │    │              │                   │    ├─■──voted_vote_votes_poll_thanks voted ── Topic: 137
#      │    │         │    │              │                   │    └─■──voted_voted for_thanks voted_hope she_she ── Topic: 520
#      │    │         │    │              │                   └─■──thanks voted_voted thanks_voted_voted good_luck thanks ── Topic: 1397
#      │    │         │    │              └─birthday_happy birthday_happy_thanks happy_birthday happy
#      │    │         │    │                   ├─■──birthday happy_happy birthday_birthday_happy_mate happy ── Topic: 589
#      │    │         │    │                   └─birthday_happy birthday_happy_thanks happy_birthday thanks
#      │    │         │    │                        ├─birthday_happy birthday_happy_thanks happy_birthday to
#      │    │         │    │                        │    ├─■──birthday_happy birthday_drinking2_happy_thanks happy ── Topic: 1090
#      │    │         │    │                        │    └─■──birthday_happy birthday_happy_thanks happy_birthday to ── Topic: 63
#      │    │         │    │                        └─■──birthday thanks_thanks happy_happy birthday_birthday_birthday mate ── Topic: 776
#      │    │         │    └─com get_followers youtube_youtube views_get instant_instagram followers
#      │    │         │         ├─com get_followers youtube_youtube views_get instant_instagram followers
#      │    │         │         │    ├─followers youtube_youtube views_get instant_instagram followers_followers
#      │    │         │         │    │    ├─instantproxies com_instagram followers_instantproxies_instant instagram_followers
#      │    │         │         │    │    │    ├─■──as 27_20 best_27 month_from group_proxies get ── Topic: 1016
#      │    │         │         │    │    │    └─instagram followers_instantproxies com_instantproxies_instant instagram_followers
#      │    │         │         │    │    │         ├─instagram followers_more instantproxies_followers_instantproxies com_instantproxies
#      │    │         │         │    │    │         │    ├─■──followers_instagram followers_web elite_fed instagram_real drip ── Topic: 398
#      │    │         │         │    │    │         │    └─■──com blazing_proxies unlimited_fast private_blazing fast_blazing ── Topic: 307
#      │    │         │         │    │    │         └─rd_high rd_25 high_private proxi_web private
#      │    │         │         │    │    │              ├─■──1074 da_rd 1074_41 tf_1074_da 41 ── Topic: 1228
#      │    │         │         │    │    │              └─■──high rd_25 high_rd_tumblrs invest_rd tumblrs ── Topic: 821
#      │    │         │         │    │    └─followers youtube_youtube views_com get_get instant_instant
#      │    │         │         │    │         ├─cart project_providers serviceproviderpro_serviceproviderpro socialsbox_serviceproviderpro_views yt
#      │    │         │         │    │         │    ├─■──more signature_signature line_line available_serviceproviderpro socialsbox_cart project ── Topic: 517
#      │    │         │         │    │         │    └─■──signature shopping_text line_rent in_or banner_line or ── Topic: 292
#      │    │         │         │    │         └─facebook likes_signature link_youtube views_followers youtube_finding bugs
#      │    │         │         │    │              ├─■──websites signature_more ebook_finding bugs_ebook make_money finding ── Topic: 205
#      │    │         │         │    │              └─fans com_instant fans_likes instagram_views more_real facebook
#      │    │         │         │    │                   ├─■──youtube views_views ig_rankshomepagelinks instant_rankshomepagelinks_instant youtube ── Topic: 718
#      │    │         │         │    │                   └─■──answers level_25 only_level accounts_accounts 25_than yahoo ── Topic: 574
#      │    │         │         │    └─com get_indexification com_indexed captchatronix_indexed dirty_fastest captcha
#      │    │         │         │         ├─com get_indexification com_indexed captchatronix_indexed dirty_fastest captcha
#      │    │         │         │         │    ├─■──com get_indexed dirty_indexed captchatronix_fastest captcha_service indexification ── Topic: 1346
#      │    │         │         │         │    └─■──com get_indexification com_indexed captchatronix_indexed dirty_fastest captcha ── Topic: 258
#      │    │         │         │         └─■──com get_indexed captchatronix_indexed dirty_fastest captcha_service indexification ── Topic: 1401
#      │    │         │         └─welcome aboard_aboard_aboard welcome_welcome_aboard mate
#      │    │         │              ├─welcome aboard_aboard_aboard welcome_welcome_aboard mate
#      │    │         │              │    ├─■──aboard mate_welcome aboard_mate welcome_aboard_mate ── Topic: 1368
#      │    │         │              │    └─welcome aboard_aboard_aboard welcome_welcome_aboard thanks
#      │    │         │              │         ├─aboard_welcome aboard_welcome_aboard thanks_aboard welcome
#      │    │         │              │         │    ├─■──welcome aboard_aboard_welcome_aboard mate_journey welcome ── Topic: 1231
#      │    │         │              │         │    └─■──aboard_welcome aboard_aboard thanks_welcome_aboard welcome ── Topic: 726
#      │    │         │              │         └─■──aboard welcome_welcome aboard_aboard_welcome_op welcome ── Topic: 1171
#      │    │         │              └─■──ship bhw_good ship_aboard the_learn earn_read learn ── Topic: 1358
#      │    │         └─18 2016_moderator may_may 18_by moderator_edited by
#      │    │              ├─moderator may_18 2016_may 18_by moderator_edited by
#      │    │              │    ├─■──18 2016_may 18_moderator may_by moderator_edited by ── Topic: 1122
#      │    │              │    └─■──moderator may_18 2016_may 18_by moderator_edited by ── Topic: 341
#      │    │              └─2016 last_18 2016_may 18_moderator may_by moderator
#      │    │                   ├─2016 last_18 2016_may 18_moderator may_by moderator
#      │    │                   │    ├─■──2016 last_18 2016_may 18_moderator may_by moderator ── Topic: 604
#      │    │                   │    └─■──2016 last_18 2016_may 18_moderator may_by moderator ── Topic: 985
#      │    │                   └─■──2016 last_18 2016_may 18_moderator may_by moderator ── Topic: 1411
#      │    └─to bhw_welcome to_bhw welcome_bhw_welcome
#      │         ├─to bhw_welcome to_bhw welcome_bhw_welcome
#      │         │    ├─to bhw_bhw_welcome to_welcome_bhw hi
#      │         │    │    ├─■──bhw hi_hi welcome_to bhw_welcome to_welcome ── Topic: 858
#      │         │    │    └─bhw_to bhw_welcome to_welcome_bhw is
#      │         │    │         ├─bhw_to bhw_welcome to_welcome_bhw is
#      │         │    │         │    ├─■──bhw_to bhw_welcome to_welcome_bhw is ── Topic: 17
#      │         │    │         │    └─to bhw_welcome to_welcome_bhw_bhw hi
#      │         │    │         │         ├─■──to bhw_welcome to_welcome_bhw community_bhw ── Topic: 419
#      │         │    │         │         └─■──to bhw_welcome to_bhw hi_welcome_bhw ── Topic: 454
#      │         │    │         └─■──bhw hello_to bhw_hello welcome_welcome to_hello and ── Topic: 820
#      │         │    └─bhw welcome_to bhw_welcome to_welcome_bhw
#      │         │         ├─bhw welcome_to bhw_welcome to_welcome_bhw
#      │         │         │    ├─bhw welcome_to bhw_welcome to_welcome_bhw
#      │         │         │    │    ├─bhw welcome_to bhw_welcome to_welcome_bhw
#      │         │         │    │    │    ├─■──bhw welcome_to bhw_welcome to_welcome_bhw ── Topic: 571
#      │         │         │    │    │    └─■──bhw welcome_to bhw_welcome to_welcome_bhw ── Topic: 337
#      │         │         │    │    └─■──bhw welcome_to bhw_welcome to_welcome_bhw ── Topic: 466
#      │         │         │    └─■──bhw welcome_welcome to_to bhw_welcome_bhw ── Topic: 483
#      │         │         └─■──bhw mate_mate welcome_to bhw_welcome to_bhw buddy ── Topic: 764
#      │         └─thanks welcome_bhw thanks_to bhw_welcome to_welcome
#      │              ├─bhw thanks_thanks welcome_to bhw_welcome to_welcome
#      │              │    ├─■──bhw thanks_thanks welcome_to bhw_welcome to_welcome ── Topic: 592
#      │              │    └─■──bhw thanks_thanks welcome_to bhw_welcome to_welcome ── Topic: 1442
#      │              └─■──welcome thanks_thanks welcome_welcome_thanks_welcome absurtuk ── Topic: 1369
#      └─thanks thanks_thanks_10 thanks_thanks 10_welcome dude
#           ├─thanks thanks_thanks_welcome dude_dude welcome_thankyou thanks
#           │    ├─■──thanks thanks_welcome dude_dude welcome_thanks_dude ── Topic: 753
#           │    └─thanks thanks_thanks_thankyou thanks_thanks thankyou_thankyou
#           │         ├─thanks thanks_thanks_thanks shar_thanks amateurs_amateurs thanks
#           │         │    ├─■──thanks thanks_thanks_thanks nee_nee thanks_wooten thanks ── Topic: 1446
#           │         │    └─thanks thanks_thanks_thanks shar_thanks amateurs_amateurs thanks
#           │         │         ├─thanks thanks_thanks_thanks shar_thanks amateurs_amateurs thanks
#           │         │         │    ├─■──thanks thanks_thanks_lawd thanks_oh lawd_lawd ── Topic: 1182
#           │         │         │    └─thanks thanks_thanks_thanks shar_thanks amateurs_amateurs thanks
#           │         │         │         ├─thanks thanks_thanks_thanks shar_thanks amateurs_amateurs thanks
#           │         │         │         │    ├─■──thanks thanks_thanks_thanks amateurs_amateurs thanks_amateurs ── Topic: 577
#           │         │         │         │    └─thanks thanks_thanks_thanks shar_shar thanks_ubjelly
#           │         │         │         │         ├─thanks thanks_thanks_boxes ubjelly_thanks tissue_ubjelly thanks
#           │         │         │         │         │    ├─■──thanks thanks_thanks_like thanks_thanks looks_looks like ── Topic: 1304
#           │         │         │         │         │    └─thanks thanks_thanks_boxes ubjelly_ubjelly_thanks tissue
#           │         │         │         │         │         ├─thanks thanks_thanks_thanks puta_puta thanks_thanks co
#           │         │         │         │         │         │    ├─■──thanks thanks_thanks_thanks puta_puta thanks_thanks co ── Topic: 104
#           │         │         │         │         │         │    └─■──thanks thanks_thanks___ ── Topic: 624
#           │         │         │         │         │         └─■──thanks thanks_thanks_ubjelly_ubjelly thanks_thanks tissue ── Topic: 340
#           │         │         │         │         └─■──thanks thanks_thanks_thanks shar_shar thanks_thanks younube ── Topic: 403
#           │         │         │         └─■──thanks thanks_thanks_whoa thanks_thanks xd_thanks whoa ── Topic: 969
#           │         │         └─■──thanks thanks_thanks_thanks voila_voila thanks_thanks roasted ── Topic: 1295
#           │         └─■──thanks thanks_thankyou thanks_thanks thankyou_thanks_thankyou ── Topic: 752
#           └─■──thanks thanks_10 thanks_thanks 10_thanks_10 ── Topic: 965

# %%
if sample:
  topic_model_gpu.save("sample_model")
else:
  topic_model_gpu.save("complex_model")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /opt/conda/lib/python3.8/site-packages/scipy/sparse/_index.py:124: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [26], in <module>
#       1 if sample:
# ----> 2   topic_model_gpu.save("sample_model")
#       3 else:
#       4   topic_model_gpu.save("complex_model")
#
# File /opt/conda/lib/python3.8/site-packages/bertopic/_bertopic.py:2751, in BERTopic.save(self, path, save_embedding_model)
#    2749     self.embedding_model = embedding_model
#    2750 else:
# -> 2751     joblib.dump(self, file)
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:484, in dump(value, filename, compress, protocol, cache_size)
#     482         NumpyPickler(f, protocol=protocol).dump(value)
#     483 else:
# --> 484     NumpyPickler(filename, protocol=protocol).dump(value)
#     486 # If the target container is a file object, nothing is returned.
#     487 if is_fileobj:
#
# File /opt/conda/lib/python3.8/pickle.py:485, in _Pickler.dump(self, obj)
#     483 if self.proto >= 4:
#     484     self.framer.start_framing()
# --> 485 self.save(obj)
#     486 self.write(STOP)
#     487 self.framer.end_framing()
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:284, in NumpyPickler.save(self, obj)
#     281     wrapper.write_array(obj, self)
#     282     return
# --> 284 return Pickler.save(self, obj)
#
# File /opt/conda/lib/python3.8/pickle.py:601, in _Pickler.save(self, obj, save_persistent_id)
#     597     raise PicklingError("Tuple returned by %s must have "
#     598                         "two to six elements" % reduce)
#     600 # Save the reduce() output and finally memoize the object
# --> 601 self.save_reduce(obj=obj, *rv)
#
# File /opt/conda/lib/python3.8/pickle.py:715, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713 if state is not None:
#     714     if state_setter is None:
# --> 715         save(state)
#     716         write(BUILD)
#     717     else:
#     718         # If a state_setter is specified, call it instead of load_build
#     719         # to update obj's with its previous state.
#     720         # First, push state_setter and its tuple of expected arguments
#     721         # (obj, state) onto the stack.
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:284, in NumpyPickler.save(self, obj)
#     281     wrapper.write_array(obj, self)
#     282     return
# --> 284 return Pickler.save(self, obj)
#
# File /opt/conda/lib/python3.8/pickle.py:558, in _Pickler.save(self, obj, save_persistent_id)
#     556 f = self.dispatch.get(t)
#     557 if f is not None:
# --> 558     f(self, obj)  # Call unbound method with explicit self
#     559     return
#     561 # Check private dispatch table if any, or else
#     562 # copyreg.dispatch_table
#
# File /opt/conda/lib/python3.8/pickle.py:969, in _Pickler.save_dict(self, obj)
#     966     self.write(MARK + DICT)
#     968 self.memoize(obj)
# --> 969 self._batch_setitems(obj.items())
#
# File /opt/conda/lib/python3.8/pickle.py:995, in _Pickler._batch_setitems(self, items)
#     993     for k, v in tmp:
#     994         save(k)
# --> 995         save(v)
#     996     write(SETITEMS)
#     997 elif n:
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:284, in NumpyPickler.save(self, obj)
#     281     wrapper.write_array(obj, self)
#     282     return
# --> 284 return Pickler.save(self, obj)
#
# File /opt/conda/lib/python3.8/pickle.py:601, in _Pickler.save(self, obj, save_persistent_id)
#     597     raise PicklingError("Tuple returned by %s must have "
#     598                         "two to six elements" % reduce)
#     600 # Save the reduce() output and finally memoize the object
# --> 601 self.save_reduce(obj=obj, *rv)
#
# File /opt/conda/lib/python3.8/pickle.py:715, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713 if state is not None:
#     714     if state_setter is None:
# --> 715         save(state)
#     716         write(BUILD)
#     717     else:
#     718         # If a state_setter is specified, call it instead of load_build
#     719         # to update obj's with its previous state.
#     720         # First, push state_setter and its tuple of expected arguments
#     721         # (obj, state) onto the stack.
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:284, in NumpyPickler.save(self, obj)
#     281     wrapper.write_array(obj, self)
#     282     return
# --> 284 return Pickler.save(self, obj)
#
# File /opt/conda/lib/python3.8/pickle.py:558, in _Pickler.save(self, obj, save_persistent_id)
#     556 f = self.dispatch.get(t)
#     557 if f is not None:
# --> 558     f(self, obj)  # Call unbound method with explicit self
#     559     return
#     561 # Check private dispatch table if any, or else
#     562 # copyreg.dispatch_table
#
# File /opt/conda/lib/python3.8/pickle.py:969, in _Pickler.save_dict(self, obj)
#     966     self.write(MARK + DICT)
#     968 self.memoize(obj)
# --> 969 self._batch_setitems(obj.items())
#
# File /opt/conda/lib/python3.8/pickle.py:995, in _Pickler._batch_setitems(self, items)
#     993     for k, v in tmp:
#     994         save(k)
# --> 995         save(v)
#     996     write(SETITEMS)
#     997 elif n:
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:284, in NumpyPickler.save(self, obj)
#     281     wrapper.write_array(obj, self)
#     282     return
# --> 284 return Pickler.save(self, obj)
#
# File /opt/conda/lib/python3.8/pickle.py:601, in _Pickler.save(self, obj, save_persistent_id)
#     597     raise PicklingError("Tuple returned by %s must have "
#     598                         "two to six elements" % reduce)
#     600 # Save the reduce() output and finally memoize the object
# --> 601 self.save_reduce(obj=obj, *rv)
#
# File /opt/conda/lib/python3.8/pickle.py:715, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713 if state is not None:
#     714     if state_setter is None:
# --> 715         save(state)
#     716         write(BUILD)
#     717     else:
#     718         # If a state_setter is specified, call it instead of load_build
#     719         # to update obj's with its previous state.
#     720         # First, push state_setter and its tuple of expected arguments
#     721         # (obj, state) onto the stack.
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:284, in NumpyPickler.save(self, obj)
#     281     wrapper.write_array(obj, self)
#     282     return
# --> 284 return Pickler.save(self, obj)
#
# File /opt/conda/lib/python3.8/pickle.py:558, in _Pickler.save(self, obj, save_persistent_id)
#     556 f = self.dispatch.get(t)
#     557 if f is not None:
# --> 558     f(self, obj)  # Call unbound method with explicit self
#     559     return
#     561 # Check private dispatch table if any, or else
#     562 # copyreg.dispatch_table
#
# File /opt/conda/lib/python3.8/pickle.py:969, in _Pickler.save_dict(self, obj)
#     966     self.write(MARK + DICT)
#     968 self.memoize(obj)
# --> 969 self._batch_setitems(obj.items())
#
# File /opt/conda/lib/python3.8/pickle.py:995, in _Pickler._batch_setitems(self, items)
#     993     for k, v in tmp:
#     994         save(k)
# --> 995         save(v)
#     996     write(SETITEMS)
#     997 elif n:
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:284, in NumpyPickler.save(self, obj)
#     281     wrapper.write_array(obj, self)
#     282     return
# --> 284 return Pickler.save(self, obj)
#
# File /opt/conda/lib/python3.8/pickle.py:601, in _Pickler.save(self, obj, save_persistent_id)
#     597     raise PicklingError("Tuple returned by %s must have "
#     598                         "two to six elements" % reduce)
#     600 # Save the reduce() output and finally memoize the object
# --> 601 self.save_reduce(obj=obj, *rv)
#
# File /opt/conda/lib/python3.8/pickle.py:690, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     688 else:
#     689     save(func)
# --> 690     save(args)
#     691     write(REDUCE)
#     693 if obj is not None:
#     694     # If the object is already in the memo, this means it is
#     695     # recursive. In this case, throw away everything we put on the
#     696     # stack, and fetch the object back from the memo.
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:284, in NumpyPickler.save(self, obj)
#     281     wrapper.write_array(obj, self)
#     282     return
# --> 284 return Pickler.save(self, obj)
#
# File /opt/conda/lib/python3.8/pickle.py:558, in _Pickler.save(self, obj, save_persistent_id)
#     556 f = self.dispatch.get(t)
#     557 if f is not None:
# --> 558     f(self, obj)  # Call unbound method with explicit self
#     559     return
#     561 # Check private dispatch table if any, or else
#     562 # copyreg.dispatch_table
#
# File /opt/conda/lib/python3.8/pickle.py:884, in _Pickler.save_tuple(self, obj)
#     882 if n <= 3 and self.proto >= 2:
#     883     for element in obj:
# --> 884         save(element)
#     885     # Subtle.  Same as in the big comment below.
#     886     if id(obj) in memo:
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:284, in NumpyPickler.save(self, obj)
#     281     wrapper.write_array(obj, self)
#     282     return
# --> 284 return Pickler.save(self, obj)
#
# File /opt/conda/lib/python3.8/pickle.py:601, in _Pickler.save(self, obj, save_persistent_id)
#     597     raise PicklingError("Tuple returned by %s must have "
#     598                         "two to six elements" % reduce)
#     600 # Save the reduce() output and finally memoize the object
# --> 601 self.save_reduce(obj=obj, *rv)
#
# File /opt/conda/lib/python3.8/pickle.py:690, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     688 else:
#     689     save(func)
# --> 690     save(args)
#     691     write(REDUCE)
#     693 if obj is not None:
#     694     # If the object is already in the memo, this means it is
#     695     # recursive. In this case, throw away everything we put on the
#     696     # stack, and fetch the object back from the memo.
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:284, in NumpyPickler.save(self, obj)
#     281     wrapper.write_array(obj, self)
#     282     return
# --> 284 return Pickler.save(self, obj)
#
# File /opt/conda/lib/python3.8/pickle.py:558, in _Pickler.save(self, obj, save_persistent_id)
#     556 f = self.dispatch.get(t)
#     557 if f is not None:
# --> 558     f(self, obj)  # Call unbound method with explicit self
#     559     return
#     561 # Check private dispatch table if any, or else
#     562 # copyreg.dispatch_table
#
# File /opt/conda/lib/python3.8/pickle.py:884, in _Pickler.save_tuple(self, obj)
#     882 if n <= 3 and self.proto >= 2:
#     883     for element in obj:
# --> 884         save(element)
#     885     # Subtle.  Same as in the big comment below.
#     886     if id(obj) in memo:
#
# File /opt/conda/lib/python3.8/site-packages/joblib/numpy_pickle.py:284, in NumpyPickler.save(self, obj)
#     281     wrapper.write_array(obj, self)
#     282     return
# --> 284 return Pickler.save(self, obj)
#
# File /opt/conda/lib/python3.8/pickle.py:558, in _Pickler.save(self, obj, save_persistent_id)
#     556 f = self.dispatch.get(t)
#     557 if f is not None:
# --> 558     f(self, obj)  # Call unbound method with explicit self
#     559     return
#     561 # Check private dispatch table if any, or else
#     562 # copyreg.dispatch_table
#
# File /opt/conda/lib/python3.8/pickle.py:801, in _Pickler.save_bytes(self, obj)
#     799     self._write_large_bytes(BINBYTES8 + pack("<Q", n), obj)
#     800 elif n >= self.framer._FRAME_SIZE_TARGET:
# --> 801     self._write_large_bytes(BINBYTES + pack("<I", n), obj)
#     802 else:
#     803     self.write(BINBYTES + pack("<I", n) + obj)
#
# File /opt/conda/lib/python3.8/pickle.py:260, in _Framer.write_large_bytes(self, header, payload)
#     253 # Perform direct write of the header and payload of the large binary
#     254 # object. Be careful not to concatenate the header and the payload
#     255 # prior to calling 'write' as we do not want to allocate a large
#     256 # temporary bytes object.
#     257 # We intentionally do not insert a protocol 4 frame opcode to make
#     258 # it possible to optimize file.read calls in the loader.
#     259 write(header)
# --> 260 write(payload)
#
# OSError: [Errno 28] No space left on device

# %%
np.__version__

# %%
# !pip show bertopic | grep Version

# %%
# !pip show tensorflow | grep Version

# %%
# !python --version

# %%
# !pip show torch | grep Version

# %%
#
