# %% [markdown]
# <a href="https://colab.research.google.com/github/oscarWoj/CISC499/blob/main/bertmodel_for_first_3000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Refer to this if you have any questions: https://towardsdatascience.com/interactive-topic-modeling-with-bertopic-1ea55e7d73d8

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Data will be downloaded from google drive folder

# %%
# !pip install bertopic[visualization]
# !apt-get install unzip
# !pip install gdown
# !pip install --upgrade gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.9/103.9 KB 7.7 MB/s eta 0:00:00
# WARNING: bertopic 0.13.0 does not provide the extra 'visualization'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 47.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.4/662.4 KB 51.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 78.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.7 MB/s eta 0:00:00
# ...

# %%
import csv
import gdown
from bertopic import BERTopic

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1Xtc9eTSyjQEaGoRgU9VGlz6YB4SvPoMc/view?usp=sharing
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Xtc9eTSyjQEaGoRgU9VGlz6YB4SvPoMc
# To: /content/outputfile.csv.zip
# 100% 829M/829M [00:11<00:00, 70.2MB/s]

# %%
# !unzip /content/outputfile.csv.zip
# Out:
# Archive:  /content/outputfile.csv.zip
#   inflating: outputfile.csv
#   inflating: __MACOSX/._outputfile.csv

# %%
data = [] ## IF the system keeps running out of memory, we might have to change this list of string into a numpy object thingn

# %%
with open('/content/outputfile.csv', newline='') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row[0])

# %%
data[0] # Later: maybe check if row is a header such as: "txtBody_Clean" and skip that append ^^
# Out:
# 'txtBody_Clean'

# %%
type(data[0]) # This should be string not list
# Out:
# str

# %% [markdown]
# ## Implementing and running the model

# %%
model = BERTopic()
topics, probs = model.fit_transform(data[:3000])
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
model.get_topic_freq().head()
# Out:
#    Topic  Count
# 0     -1    948
# 1      0    133
# 2      1    128
# 3      2    115
# 4      3    106

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
